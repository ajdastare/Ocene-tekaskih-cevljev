# %%
# naložimo paket pandas
import pandas as pd
import matplotlib.pyplot as plt

# %%
modeli = pd.read_csv('obdelani-podatki/vsi-modeli.csv', index_col='ocena')

# ker bomo delali z velikimi razpredelnicami, povemo, da naj se vedno izpiše le 20 vrstic
pd.options.display.max_rows = 20

# %%
#head dobimo prvih n podatkov filmi.head(n) ....
modeli.head(30)
# Out:
#              znamka                                     model  teren  cena  \
# ocena
# 4.7            Nike                    Nike Air Zoom Winflo 4   Road   110
# 4.7           Altra                       Altra Escalante 1.5   Road   160
# 4.8         Merrell  Merrell All Out Crush Tough Mudder 2 BOA  Trail   150
# 4.6        Skechers                     Skechers GOrun Ride 7   Road   110
# 4.5          Adidas                        Adidas Solar Glide   Road   170
# 4.6      Xero Shoes                           Xero Shoes Prio  Trail   110
# 4.8          Reebok                     Reebok Zigwild TR 5.0   Road   140
# 4.6           Asics                       Asics Gel Kayano 25   Road   190
# 4.6         Salomon                      Salomon Sonic RA Max   Road   160
# 4.7          Adidas                   Adidas Ultraboost Clima   Road   270
# ...             ...                                       ...    ...   ...
# ...

# %%
modeli.sort_values(['ocena', 'cena'], ascending=[False, False]).head(20)
# Out:
#                znamka                                     model  teren  cena  \
# ocena
# 5.0            Reebok                    Reebok OSR Grasse Road   Road   150
# 4.9           Salomon                     Salomon S-Lab Sense 7  Trail   220
# 4.9            Inov-8                    Inov-8 Roclite 320 GTX  Trail   190
# 4.9            Adidas                    Adidas Supernova Trail  Trail   170
# 4.9             Asics                   Asics DynaFlyte 3 Sound   Road   160
# 4.9     Topo Athletic                Topo Athletic Runventure 2  Trail   140
# 4.9            Reebok                      Reebok Instalite Lux   Road    80
# 4.8            Adidas                Adidas Ultra Boost Uncaged   Road   220
# 4.8       New Balance                    New Balance 880 v8 GTX   Road   170
# 4.8    The North Face                 The North Face Endurus TR  Trail   160
# 4.8           Merrell  Merrell All Out Crush Tough Mudder 2 BOA  Trail   150
# ...

# %%
modeli[modeli.cena>=100].sort_values(['cena'],ascending = True)
# Out:
#               znamka                              model  teren  cena  \
# ocena
# 4.3          Merrell              Merrell Vapor Glove 3   Road   100
# 4.5           Adidas               Adidas Mana Bounce 2   Road   100
# 4.3     Under Armour   Under Armour Micro G Speed Swift   Road   100
# 4.1     Under Armour               Under Armour Drift 2   Road   100
# 4.2     Under Armour      Under Armour Charged Bandit 4   Road   100
# 4.2            Asics                   Asics Gel Flux 5   Road   100
# 4.2            Asics               Asics Gel Kenun Lyte   Road   100
# 3.9    Vivobarefoot          Vivobarefoot Ultra 3 Bloom  Trail   100
# 4.2           Adidas                Adidas Vigor Bounce  Trail   100
# 4.3             Nike             Nike Air Max Advantage   Road   100
# ...              ...                                ...    ...   ...
# 4.6             Nike      Nike LunarEpic Flyknit Shield   Road   240
# ...

# %%
#Najboljši čevlji za tip terena Road po oceni in številu ocen
modeli.sort_values(['ocena','stevilo ocen'], ascending = [False,False]).head(10)
# Out:
#               znamka                                     model  teren  cena  \
# ocena
# 5.0           Reebok                    Reebok OSR Grasse Road   Road   150
# 4.9           Adidas                    Adidas Supernova Trail  Trail   170
# 4.9    Topo Athletic                Topo Athletic Runventure 2  Trail   140
# 4.9            Asics                   Asics DynaFlyte 3 Sound   Road   160
# 4.9           Inov-8                    Inov-8 Roclite 320 GTX  Trail   190
# 4.9           Reebok                      Reebok Instalite Lux   Road    80
# 4.9          Salomon                     Salomon S-Lab Sense 7  Trail   220
# 4.8           Adidas                Adidas Ultra Boost Uncaged   Road   220
# 4.8           Reebok                     Reebok Zigwild TR 5.0   Road   140
# 4.8          Merrell  Merrell All Out Crush Tough Mudder 2 BOA  Trail   150
#
#        stevilo ocen
# ocena
# 5.0             7.0
# 4.9            21.0
# 4.9            20.0
# 4.9            16.0
# ...
